# %%
#%%python3 -m pip install pandas
import pandas as pd

states = pd.read_csv('states.csv')

print(states.head())
# Out:
#           state     month  day  year
# 0      Delaware  December    7  1787
# 1  Pennsylvania  December   12  1787
# 2     NewJersey  December   18  1787
# 3       Georgia   January    2  1788
# 4   Connecticut   January    9  1788

# %%
import matplotlib.pyplot as plt

#plt.scatter(states_pd['f_year'], states_pd['states'])

states['year'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
x = states['year']
y = states.index

plt.plot(x, y)

#states['year'].sort_index().cumsum().plot()

# https://stackoverflow.com/questions/48739374/pandas-plot-cumulative-sum-of-counters-over-time
#states.set_index('year').cumsum().plot()

#states.set__index('year')
